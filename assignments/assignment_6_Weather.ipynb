# %% [markdown]
# # Assignment 6 - Timeseries and Synthetic Data

# %% [markdown]
# #### Author: Elaine R. Cazeta

# %% [markdown]
# ## - Part 1:
# Get the data from this [link](https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv).
#
# Plot:
#
# - The temperature
# - The mean temperature each day
# - The mean temperature for each month

# %%
# Importing pandas library for data manipulation:
import pandas as pd

# Importing Seaborn library to create plots:
import seaborn as sns

# %%
# Source: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
names = ["date", "temp", "wdsp"] # List of columns that will be used
# Skipping the first 24 rows as they have irrelevant data:
df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv", header= None, names = names, index_col=False, skiprows=24)
df.head(3)
# Out:
# /tmp/ipykernel_4277/1174176032.py:2: DtypeWarning: Columns (2,10,12,14,15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv",header= None, names = names, index_col=False, skiprows=24)
# /tmp/ipykernel_4277/1174176032.py:2: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv",header= None, names = names, index_col=False, skiprows=24)
#                 date  temp wdsp
# 0  10-apr-1996 14:00     0  0.0
# 1  31-jul-1996 08:00     0  0.0
# 2  31-jul-1996 09:00     0  0.0
